# %%
# ДЗ:
"""
- Повторить: функции, LEGB
- Доделать прошлое ДЗ
- Решить задачу
"""

# %%
"""
### Напиши функцию, которая будет считать предложения в тексте.

Функция:
- принимает текст
- возвращает кол-во предложений в тексте в виде строки: "В тексте N предложений"

Задача под звёздочкой:
- Если предложений больше 5, то так же будет выводиться сообщение "Длинный текст"
- Если больше вух восклицательных знаков, то так же будет выводиться сообщение "Текст воодушевляет"
"""
